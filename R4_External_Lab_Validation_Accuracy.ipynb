# %%
# Import important library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Read the input file and check the data dimension

# %%
cred = pd.read_csv('german_credit.csv')
cred.head()
# Out:
#    default account_check_status  duration_in_month  \
# 0        0               < 0 DM                  6
# 1        1    0 <= ... < 200 DM                 48
# 2        0  no checking account                 12
# 3        0               < 0 DM                 42
# 4        1               < 0 DM                 24
#
#                                       credit_history  \
# 0  critical account/ other credits existing (not ...
# 1           existing credits paid back duly till now
# 2  critical account/ other credits existing (not ...
# 3           existing credits paid back duly till now
# 4                    delay in paying off in the past
#
#                         purpose  credit_amount                      savings  \
# 0           domestic appliances           1169  unknown/ no savings account
# 1           domestic appliances           5951                 ... < 100 DM
# 2  (vacation - does not exist?)           2096                 ... < 100 DM
# ...

# %%
cred.shape
# Out:
# (1000, 21)

# %%
cred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
# default                       1000 non-null int64
# account_check_status          1000 non-null object
# duration_in_month             1000 non-null int64
# credit_history                1000 non-null object
# purpose                       1000 non-null object
# credit_amount                 1000 non-null int64
# savings                       1000 non-null object
# present_emp_since             1000 non-null object
# installment_as_income_perc    1000 non-null int64
# personal_status_sex           1000 non-null object
# other_debtors                 1000 non-null object
# present_res_since             1000 non-null int64
# property                      1000 non-null object
# age                           1000 non-null int64
# other_installment_plans       1000 non-null object
# housing                       1000 non-null object
# ...

# %%
# You can access from https://www.kaggle.com/uciml/german-credit
#Read input file and understand the data
# "default" is my dependent variable
# Out:
# (1000, 21)
# Index(['default', 'account_check_status', 'duration_in_month',
#        'credit_history', 'purpose', 'credit_amount', 'savings',
#        'present_emp_since', 'installment_as_income_perc',
#        'personal_status_sex', 'other_debtors', 'present_res_since', 'property',
#        'age', 'other_installment_plans', 'housing', 'credits_this_bank', 'job',
#        'people_under_maintenance', 'telephone', 'foreign_worker'],
#       dtype='object')
#    default account_check_status  duration_in_month  \
# 0        0               < 0 DM                  6
# 1        1    0 <= ... < 200 DM                 48
# 2        0  no checking account                 12
# 3        0               < 0 DM                 42
# 4        1               < 0 DM                 24
#
#                                       credit_history  \
# 0  critical account/ other credits existing (not ...
# 1           existing credits paid back duly till now
# ...

# %% [markdown]
# ### Q1 Randomly select 50% data for this use case( 1 Marks)
# ###### Hint: Use train_test_split

# %%
from sklearn.model_selection import train_test_split

# %%
# Copy all the independent/predictor variables into X dataframe. Since 'default' is dependent variable drop it
X = cred.drop('default', axis=1)

# Copy the 'default' column alone into the y dataframe. This is the dependent variable
y = cred[['default']]

# %%
X.head()
# Out:
#   account_check_status  duration_in_month  \
# 0               < 0 DM                  6
# 1    0 <= ... < 200 DM                 48
# 2  no checking account                 12
# 3               < 0 DM                 42
# 4               < 0 DM                 24
#
#                                       credit_history  \
# 0  critical account/ other credits existing (not ...
# 1           existing credits paid back duly till now
# 2  critical account/ other credits existing (not ...
# 3           existing credits paid back duly till now
# 4                    delay in paying off in the past
#
#                         purpose  credit_amount                      savings  \
# 0           domestic appliances           1169  unknown/ no savings account
# 1           domestic appliances           5951                 ... < 100 DM
# 2  (vacation - does not exist?)           2096                 ... < 100 DM
# 3              radio/television           7882                 ... < 100 DM
# ...

# %%
y.head()
# Out:
#    default
# 0        0
# 1        1
# 2        0
# 3        0
# 4        1

# %%
# Split X and y into training and test set in 50:50 ratio

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.50, random_state=1)

# %%
from sklearn.model_selection import train_test_split
train_data,test_data = train_test_split(cred,test_size=0.5,shuffle=True,stratify=cred['default'])
print(train_data.shape,test_data.shape)
y_train = train_data['default']
x_train = train_data.drop('default',inplace=False,axis=1)
# Out:
# (500, 21) (500, 21)

# %%
# Lets build a Ensemble model but need to modify the dataset first

# %% [markdown]
# ### Q2.Prepare the model data by converting non-numeric to dummy ( 1 Marks)
# ##### Hint: Use get_dummies

# %%
cred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
# default                       1000 non-null int64
# account_check_status          1000 non-null object
# duration_in_month             1000 non-null int64
# credit_history                1000 non-null object
# purpose                       1000 non-null object
# credit_amount                 1000 non-null int64
# savings                       1000 non-null object
# present_emp_since             1000 non-null object
# installment_as_income_perc    1000 non-null int64
# personal_status_sex           1000 non-null object
# other_debtors                 1000 non-null object
# present_res_since             1000 non-null int64
# property                      1000 non-null object
# age                           1000 non-null int64
# other_installment_plans       1000 non-null object
# housing                       1000 non-null object
# ...

# %%
cred.columns
# Out:
# Index(['default', 'account_check_status', 'duration_in_month',
#        'credit_history', 'purpose', 'credit_amount', 'savings',
#        'present_emp_since', 'installment_as_income_perc',
#        'personal_status_sex', 'other_debtors', 'present_res_since', 'property',
#        'age', 'other_installment_plans', 'housing', 'credits_this_bank', 'job',
#        'people_under_maintenance', 'telephone', 'foreign_worker'],
#       dtype='object')

# %%
# Print Shape of model data
x_train_data_tf=pd.get_dummies(x_train)
x_train_data_tf.shape
# Out:
# (500, 61)

# %%
# Print Shape of model data
# Out:
# (500, 61)

# %% [markdown]
# ### Check for highly correlated variables but don't required any treatment for this use case

# %%
x_train_data_tf.corr()
# Out:
#                                                     duration_in_month  \
# duration_in_month                                            1.000000
# credit_amount                                                0.549852
# installment_as_income_perc                                   0.143568
# present_res_since                                            0.014543
# age                                                          0.000521
# credits_this_bank                                            0.036925
# people_under_maintenance                                    -0.035242
# account_check_status_0 <= ... < 200 DM                      -0.002886
# account_check_status_< 0 DM                                  0.013142
# account_check_status_>= 200 DM / salary assignm...          -0.039220
# account_check_status_no checking account                     0.010236
# credit_history_all credits at this bank paid ba...           0.038278
# ...

# %% [markdown]
# ### Drop the original variables which are converted to dummy

# %%
#Once converted to dummies original variable gets removed.

# %% [markdown]
# ### Q3 Split Train/Test data 70:30 ratio( 1 Marks)
# ##### Hint:from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x_train_data_tf,y_train,test_size=0.3)
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (350, 61) (150, 61) (350,) (150,)

# %% [markdown]
# ### Q4 Build Random Forest Model( 1 Marks)
# #### Hint:from sklearn.ensemble import RandomForestClassifier using n_jobs=2,n_estimators=500,criterion="entropy",random_state=9999

# %%
from sklearn.ensemble import RandomForestClassifier
random_forest_model = RandomForestClassifier(n_jobs=2,n_estimators=500,criterion="entropy",random_state=9999)
random_forest_model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=2,
#             oob_score=False, random_state=9999, verbose=0,
#             warm_start=False)

# %% [markdown]
# ### Q5 Calculate Confusion Matrix and Accuracy score (1 Marks)
# ##### Hint: Use confusion_matrix and accuracy_score

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
y_predicted = random_forest_model.predict(x_test)
print("confusion matrix")
print(confusion_matrix(y_test,y_predicted))
print('')
print("accuracy score")
print(accuracy_score(y_test,y_predicted))
# Out:
# confusion matrix
# [[100   3]
#  [ 34  13]]
#
# accuracy score
# 0.7533333333333333

# %% [markdown]
# ### Q6 Show the list of the features importance( 1 Marks)

# %%
feature_importance=random_forest_model.feature_importances_
feature_importance
# Out:
# array([0.07658557, 0.10956291, 0.03426222, 0.0312496 , 0.08690734,
#        0.01907397, 0.00965664, 0.0156525 , 0.03491385, 0.00989953,
#        0.03831518, 0.00999537, 0.0280835 , 0.00983266, 0.01524257,
#        0.00759508, 0.00801304, 0.00942787, 0.02247423, 0.00806986,
#        0.01518722, 0.00301975, 0.00170885, 0.01217909, 0.00147288,
#        0.00032647, 0.00476557, 0.01819868, 0.00791519, 0.00628572,
#        0.00982007, 0.01221045, 0.01966796, 0.01378556, 0.01371455,
#        0.00582182, 0.01521195, 0.00617329, 0.01116857, 0.01563256,
#        0.00630911, 0.00615223, 0.00802508, 0.01205184, 0.01537479,
#        0.0226591 , 0.01141562, 0.0112857 , 0.01517964, 0.00621267,
#        0.00660627, 0.01546586, 0.01288217, 0.01099845, 0.01440879,
#        0.00246541, 0.0141284 , 0.0117141 , 0.01391231, 0.00177501,
#        0.00189777])

# %% [markdown]
# ### Q7 K-fold cross-validation( 2 Marks)
# ##### k-fold cross validation( without stratification)
# ##### Usually k is set as 10-20 in practical settings, depends on data set size

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
# Use below values
num_folds = 10
seed = 77

# %%
#Validate the Random Forest model build above using k fold

# %%
k_fold=KFold(n_splits=num_folds,random_state=seed)
scores=cross_val_score(random_forest_model,x_train,y_train,cv=k_fold)
scores
# Out:
# array([0.8       , 0.71428571, 0.71428571, 0.8       , 0.62857143,
#        0.8       , 0.85714286, 0.74285714, 0.71428571, 0.85714286])

# %%
#Calculate Mean score

# %%
scores.mean()
# Out:
# 0.7628571428571428

# %%
# Calculate score standard deviation using std()

# %%
scores.std()
# Out:
# 0.06886840453253686

# %% [markdown]
# # Q8 Print the confusion matrix( 1 Marks)

# %%
confusion_matrix(y_test,y_predicted)
# Out:
# array([[100,   3],
#        [ 34,  13]], dtype=int64)

# %% [markdown]
# # Q9.Classification accuracy:
# percentage of correct predictions and Calculate sensitivity (or True Positive Rate or Recall) and Precision.
# ( 1 Marks)

# %%
from sklearn.metrics import recall_score,precision_score

# %%
print('recall {}'.format(recall_score(y_test,y_predicted)))
print('precision {}'.format(precision_score(y_test,y_predicted)))
# Out:
# recall 0.2765957446808511
# precision 0.8125

# %% [markdown]
# # Q10.Plot Receiver Operating Characteristic (ROC) Curves( 1 Marks)

# %%
#Hint: Use roc_curve

# %%
from sklearn.metrics import roc_curve
roc_curve(y_test,y_predicted)
# Out:
# (array([0.        , 0.02912621, 1.        ]),
#  array([0.        , 0.27659574, 1.        ]),
#  array([2, 1, 0], dtype=int64))

# %% [markdown]
# ROC curve can help you to choose a threshold that balances sensitivity and specificity in a way that makes sense for your particular context

# %% [markdown]
# # Q11. Calculate AUC(the percentage of the ROC plot that is underneath the curve) - optional

# %%
from sklearn.metrics import roc_auc_score

# %%
roc_auc_score(y_test,y_predicted)
# Out:
# 0.6237347655443091

# %% [markdown]
# ### Bootstrapping ( Bonus)
# ##### Given a dataset of size n, a bootstrap sample is created by sampling n instances uniformly from the data (with/without replacement)
# ##### Create a model with each bootstrap sample and validate it with the test set
# ##### Final result is calculated by averaging the accuracy of models

# %%
# Number of iterations for bootstrapping
bootstrap_iteration = 10
accuracy = []

# %%
from sklearn.utils import resample
from sklearn.metrics import accuracy_score

for i in range(bootstrap_iteration):
    X_, y_ = resample(x_train, y_train)
    random_forest_model.fit(X_, y_)
    y_pred = random_forest_model.predict(x_test)
    
    acc = accuracy_score(y_pred, y_test)
    accuracy.append(acc)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-bf0f245bd1d4> in <module>
#       8
#       9     acc = accuracy_score(y_pred, y_test)
# ---> 10     accuracy.append(acc)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'append'

# %%
accuracy = np.array(accuracy)
print('Accuracy Score')
print('Avearge: ', accuracy.mean())
print('Standard deviation: ', accuracy.std())
# Out:
# Accuracy Score
# Avearge:  nan
# Standard deviation:  nan
